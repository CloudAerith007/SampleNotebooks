# %%
%%conda

env list
# Out:
# # conda environments:
# #
# base                     /opt/conda

# %%
%%conda
create -n myenv python=3.12.6 keras
# Out:
# Channels:
#  - defaults
# Platform: linux-64
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /u01/.conda/envs/myenv
#
#   added / updated specs:
#     - keras
#     - numpy[version='>=1.23.5,<2.3']
#     - python=3.12.6
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     absl-py-2.3.1              |  py312h06a4308_0         425 KB
#     aws-c-auth-0.10.1          |       h47b2149_0         118 KB
#     aws-c-cal-0.9.13           |       h1b28b03_0          53 KB
#     aws-c-common-0.12.6        |       h47b2149_0         233 KB
#     aws-c-compression-0.3.2    |       h47b2149_0          18 KB
#     aws-c-http-0.10.13         |       h47b2149_0         199 KB
#     aws-c-io-0.26.3            |       h1b29dbc_0         161 KB
#     aws-c-s3-0.12.0            |       h1b28b03_1         132 KB
# ...

# %%
%%conda 
env list
# Out:
# # conda environments:
# #
# base                     /opt/conda
# myenv                    /u01/.conda/envs/myenv

# %%
%%conda
activate myenv
# Out:
# Conda environment 'myenv' activated

# %%
%%conda
env list
# Out:
# # conda environments:
# #
# base                     /opt/conda
# myenv                    /u01/.conda/envs/myenv

# %%
%%conda
install pytorch -c pytorch
# Out:
# Channels:
#  - pytorch
#  - defaults
# Platform: linux-64
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /u01/.conda/envs/myenv
#
#   added / updated specs:
#     - pytorch
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-4.5          |         52_intel           7 KB
#     filelock-3.29.4            |  py312h06a4308_0          99 KB
#     fmt-12.1.0                 |       h44f220b_0         192 KB
#     fsspec-2026.6.0            |  py312h7040dfc_0         633 KB
#     gmp-6.3.0                  |       h6a678d5_0         608 KB
#     gmpy2-2.2.2                |  py312ha78e65c_0         264 KB
#     jinja2-3.1.6               |  py312h06a4308_0         352 KB
#     libabseil-20260107.0       | cxx17_h6199ee8_0         1.3 MB
#     libgcc-15.2.0              |       h69a1729_7         806 KB
# ...

# %%
%%conda
list
# Out:
# # packages in environment at /u01/.conda/envs/myenv:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                        main
# _openmp_mutex             4.5                    52_intel
# absl-py                   2.3.1           py312h06a4308_0
# aws-c-auth                0.10.1               h47b2149_0
# aws-c-cal                 0.9.13               h1b28b03_0
# aws-c-common              0.12.6               h47b2149_0
# aws-c-compression         0.3.2                h47b2149_0
# aws-c-http                0.10.13              h47b2149_0
# aws-c-io                  0.26.3               h1b29dbc_0
# aws-c-s3                  0.12.0               h1b28b03_1
# aws-c-sdkutils            0.2.4                h47b2149_2
# aws-checksums             0.2.10               h47b2149_0
# blas                      1.0                         mkl
# bzip2                     1.0.8                h5eee18b_6
# ...

# %%
%%conda
uninstall pytorch
# Out:
# Channels:
#  - defaults
# Platform: linux-64
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /u01/.conda/envs/myenv
#
#   removed specs:
#     - pytorch
#
#
# The following packages will be REMOVED:
#
#   filelock-3.29.4-py312h06a4308_0
#   fmt-12.1.0-h44f220b_0
#   fsspec-2026.6.0-py312h7040dfc_0
#   gmp-6.3.0-h6a678d5_0
#   gmpy2-2.2.2-py312ha78e65c_0
#   jinja2-3.1.6-py312h06a4308_0
#   libabseil-20260107.0-cxx17_h6199ee8_0
#   libgomp-15.2.0-h4751f2c_7
#   libprotobuf-6.33.5-h4435b4a_0
#   libtorch-2.12.0-cpu_mkl_h76280c8_100
#   libuv-1.52.1-heb5a705_0
#   markupsafe-3.0.3-py312h47b2149_0
#   mpc-1.3.1-h5eee18b_0
#   mpfr-4.2.1-h5eee18b_0
#   mpmath-1.3.0-py312h06a4308_0
#   networkx-3.6.1-py312h06a4308_0
#   pybind11-abi-11-hd3eb1b0_0
#   pytorch-2.12.0-cpu_mkl_py312hcc0a54a_100
#   sleef-3.9.0-libgomp_he2a70ce_2
#   sympy-1.14.0-py312h06a4308_1
#
#
# Preparing transaction: ...working... done
# ...

# %%
%%conda
list
# Out:
# # packages in environment at /u01/.conda/envs/myenv:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                        main
# _openmp_mutex             4.5                    52_intel
# absl-py                   2.3.1           py312h06a4308_0
# aws-c-auth                0.10.1               h47b2149_0
# aws-c-cal                 0.9.13               h1b28b03_0
# aws-c-common              0.12.6               h47b2149_0
# aws-c-compression         0.3.2                h47b2149_0
# aws-c-http                0.10.13              h47b2149_0
# aws-c-io                  0.26.3               h1b29dbc_0
# aws-c-s3                  0.12.0               h1b28b03_1
# aws-c-sdkutils            0.2.4                h47b2149_2
# aws-checksums             0.2.10               h47b2149_0
# blas                      1.0                         mkl
# bzip2                     1.0.8                h5eee18b_6
# ...

# %%
%%conda

deactivate
# Out:
# Conda environment 'conda' deactivated

# %%
%%conda

env remove -n myenv
# Out:
# Remove all packages in environment /u01/.conda/envs/myenv:
