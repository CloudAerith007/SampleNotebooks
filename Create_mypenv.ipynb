# %%
%%conda
create -n mypyenv -c conda-forge --strict-channel-priority python=3.12.6 tensorflow seaborn pandas=2.2.3 numpy>=1.23.5,<2.3
# Out:
# Channels:
#  - conda-forge
#  - defaults
# Platform: linux-64
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /u01/.conda/envs/mypyenv
#
#   added / updated specs:
#     - numpy[version='>=1.23.5,<2.3']
#     - pandas=2.2.3
#     - python=3.12.6
#     - seaborn
#     - tensorflow
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _x86_64-microarch-level-3  |           3_zen2          10 KB  conda-forge
#     absl-py-2.5.0              |     pyhd8ed1ab_0         112 KB  conda-forge
#     astunparse-1.6.3           |     pyhd8ed1ab_3          18 KB  conda-forge
#     aws-c-auth-0.10.4          |       hb7a77c6_1         132 KB  conda-forge
#     aws-c-cal-0.9.14           |       h2aa3ae6_4          55 KB  conda-forge
#     aws-c-common-0.14.2        |       hb03c661_0         240 KB  conda-forge
# ...

# %%
%%lcm

upload mypyenv --overwrite --description 'Install Python seaborn and tensorflow packages' -t user 'OMLUSER' -t application OML4PY
# Out:
# Uploading conda environment mypyenv
# Upload successful for conda environment mypyenv

# %%
%%lcm
list-saved-envs -e mypyenv
# Out:
# {
#   "name": "mypyenv",
#   "size": "2.5 GiB",
#   "description": "Install Python seaborn and tensorflow packages",
#   "tags": {
#     "application": "OML4PY",
#     "user": "OMLUSER"
#   },
#   "number_of_installed_packages": 158
# }

# %%
%%conda
conda activate mypyenv
# Out:
# Conda environment 'mypyenv' activated
